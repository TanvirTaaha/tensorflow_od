# %%
import tensorflow as tf

# %%
tf.__version__

# %% [markdown]
# # Install tensorflow_io and object_detection

# %%
# Install tensorflow_io
# !git clone https://github.com/tensorflow/io.git
# !cd io
# !python -W ignore setup.py -q bdist_wheel
# %pip install --no-deps dist/tensorflow_io-0.26.0-cp310-cp310-macosx_11_0_arm64.whl

# %%
# Install object_detection
# %pip install --no-deps object_detection

# %%
# %pip install --no-deps tf-models-official
# %pip install gin-config
# %pip install google-api-python-client
# %pip install kaggle kaggle opencv-python-headless sacrebleu
# %pip install oauth2client sentencepiece seqeval tensorflow-datasets
# %pip install py-cpuinfo pyyaml==5.1 tensorflow-model-optimization tensorflow-hub
# %pip install tfa_nightly

# %%
import object_detection

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ------------------------
# absl-py                       1.1.0
# appnope                       0.1.3
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.0.5
# astunparse                    1.6.3
# attrs                         21.4.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.11.1
# bleach                        5.0.0
# cached-property               1.5.2
# cachetools                    5.2.0
# certifi                       2022.5.18.1
# cffi                          1.15.0
# charset-normalizer            2.0.12
# colorama                      0.4.4
# contextlib2                   21.6.0
# cycler                        0.11.0
# Cython                        0.29.30
# debugpy                       1.6.0
# decorator                     5.1.1
# defusedxml                    0.7.1
# ...

# %%
import tensorflow_io
